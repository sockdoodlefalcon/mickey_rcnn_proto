# %%
from google_images_download import google_images_download   

imageDownloader = google_images_download.googleimagesdownload()   

#creating list of arguments
arguments = {"keywords":"hidden mickeys pinterest",
             "limit":200,
             "print_urls":True,
             "output_directory":"E:\\Work\\MachineLearning\\ML-Classes\\MSDADLT\\08152018\\updated-lab\\google-images\\",
             "chromedriver":"C:\\Programs\\chromedriver\\chromedriver.exe"}

#passing the arguments to the function
paths = imageDownloader.download(arguments)  

#printing absolute paths of the downloaded images
print(paths)
# Out:
# Item no.: 1 --> Item name = hidden mickeys pinterest
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://i.pinimg.com/originals/2e/2e/f3/2e2ef3236787efb1e7b06fb8e17f9ed1.jpg
# Completed Image ====> 1. 2e2ef3236787efb1e7b06fb8e17f9ed1.jpg
# Image URL: https://i.pinimg.com/736x/b7/5b/81/b75b810aca6acba1c978abd95e9da54b--hidden-mickeys-a-restaurant.jpg
# Completed Image ====> 2. b75b810aca6acba1c978abd95e9da54b--hidden-mickeys-a-restaurant.jpg
# Image URL: https://i.pinimg.com/236x/70/7c/5a/707c5a67750b73b3ab6567859894a870--disney-world-florida-walt-disney-world.jpg
# Completed Image ====> 3. 707c5a67750b73b3ab6567859894a870--disney-world-florida-walt-disney-world.jpg
# Image URL: https://i.pinimg.com/originals/75/1d/92/751d923716cf87fcd61f6622b33ea16a.jpg
# Completed Image ====> 4. 751d923716cf87fcd61f6622b33ea16a.jpg
# ...
